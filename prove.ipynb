# %%
import os
import git_ck 
import repo_utils as ru
import pandas as pd

# %%
   
try:
    ru.check_repo()
    ru.check_folder()
except:
    print("Warning")

# %%
ru.dataCommit()
# Out:
#                             Titolo del Commit            Data del Commit
# 0    117c84823b376902cf208c2babf1dc7f4142c912  2014-05-06 07:06:34-07:00
# 1    3f5e8ec805934ca9b0db905d093ef9949bbaf3fb  2014-05-19 08:02:02+02:00
# 2    7262545c53e58195fb58696d0e8cc5835517f527  2014-05-19 08:06:24+02:00
# 3    43f7cfecbd273c5cac4a7c3083db5b31cb67921e  2014-07-04 09:20:53+02:00
# 4    618d7f4ddf0f8e3dec259cc0d0ee2e588bf4ab65  2014-07-04 09:22:30+02:00
# ..                                        ...                        ...
# 199  3431ac1417f5cd34f8e218529abdd2edd79ece11  2023-02-01 12:19:58+01:00
# 200  8ca801da6a2aa22941d3e7b03e3edf80a866ea5b  2023-02-11 23:02:35+01:00
# 201  1994b9cb3a9bff93bf95100d398756d7f9f626c2  2023-02-12 08:11:13+01:00
# 202  7fed6067ccf34c702584810e7625ca90dba69207  2023-02-12 08:26:45+01:00
# 203  6ddaa44174d9aed3076f43a4ea7ccde8d24b04d9  2023-02-12 08:28:16+01:00
#
# [204 rows x 2 columns]

# %%
commit_hash = '6ddaa44174d9aed3076f43a4ea7ccde8d24b04d9'
git_ck.ck_metrics_for_single_commit(commit_hash)
result_df= pd.read_csv(os.path.abspath('output\\6ddaa44174d9aed3076f43a4ea7ccde8d24b04d9class.csv'))
# Out:
# fatto1

# %%
result_df
# Out:
#                                                 file  \
# 0  c:\Users\simon\Desktop\progetto ingegneria del...
# 1  c:\Users\simon\Desktop\progetto ingegneria del...
# 2  c:\Users\simon\Desktop\progetto ingegneria del...
# 3  c:\Users\simon\Desktop\progetto ingegneria del...
# 4  c:\Users\simon\Desktop\progetto ingegneria del...
# 5  c:\Users\simon\Desktop\progetto ingegneria del...
# 6  c:\Users\simon\Desktop\progetto ingegneria del...
# 7  c:\Users\simon\Desktop\progetto ingegneria del...
# 8  c:\Users\simon\Desktop\progetto ingegneria del...
#
#                                   class        type  cbo  cboModified  fanin  \
# 0             org.jfree.fx.FXGraphics2D       class   21           23      2
# 1           org.jfree.fx.GCStateHandler       class    3            5      2
# 2           org.jfree.fx.TestGraphics2D       class    6            6      0
# 3            org.jfree.fx.FXFontMetrics       class    7            9      2
# ...
