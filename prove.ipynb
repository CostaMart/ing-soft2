# %%
import os
import git_ck 
import repo_utils as ru
import pandas as pd

# %%
   
try:
    ru.check_repo()
    ru.check_folder()
except:
    print("Warning")

# %%
pd=ru.dataCommit()
pd.to_csv("C:\\Users\\simon\\Desktop\\dati importanti\\committo.csv")

# %%
commit_hash = '3baf3aa00008701df7fb8b8440a910fdb654a304'
git_ck.ck_metrics_for_single_commit(commit_hash)
result_df= pd.read_csv(os.path.abspath('output\\3baf3aa00008701df7fb8b8440a910fdb654a304class.csv'))

# %%
result_df
# Out:
#                                                 file  \
# 0  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 1  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 2  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 3  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 4  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
#
#                                   class        type  cbo  cboModified  fanin  \
# 0             org.jfree.fx.FXGraphics2D       class   17           18      1
# 1         org.jfree.fx.FXGraphicsDevice       class    1            3      2
# 2  org.jfree.fx.FXGraphicsConfiguration       class    2            4      2
# 3                  org.jfree.fx.FXHints       class    1            1      0
# 4              org.jfree.fx.FXHints$Key  innerclass    0            0      0
#
#    fanout  wmc  dit  noc  ...  assignmentsQty  mathOperationsQty  \
# 0      17  208    3    0  ...             161                 18
# 1       1    5    2    0  ...               2                  0
# 2       2   10    2    0  ...               3                  0
# 3       1    1    2    0  ...               1                  0
# 4       0    4    2    0  ...               0                  0
#
#    variablesQty  maxNestedBlocksQty  anonymousClassesQty  innerClassesQty  \
# 0           133                   3                    0                0
# 1             2                   0                    0                0
# 2             3                   1                    0                0
# 3             1                   0                    0                1
# 4             0                   1                    0                0
#
#    lambdasQty  uniqueWordsQty  modifiers  logStatementsQty
# 0           0             576          1                 0
# 1           0              30          1                 0
# 2           0              42          1                 0
# 3           0              77         17                 0
# 4           0              32          9                 0
#
# [5 rows x 52 columns]

# %%
measures = ["cbo", "wmc", "dit", "noc"]
git_ck.commit_measure(measures ,commit_hash)
# Out:
#                                   class  cbo  wmc  dit  noc
# 0             org.jfree.fx.FXGraphics2D   17  208    3    0
# 1         org.jfree.fx.FXGraphicsDevice    1    5    2    0
# 2  org.jfree.fx.FXGraphicsConfiguration    2   10    2    0
# 3                  org.jfree.fx.FXHints    1    1    2    0
# 4              org.jfree.fx.FXHints$Key    0    4    2    0

# %%
git_ck.commit_measure_avg("wmc" ,commit_hash+"class.csv")
# Out:
# 45.6

# %%
git_ck.commit_for_year(2017)
# Out:
# Sto facendo cose
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> git_ck.commit_for_year(2017)
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\git_ck.py:90, in commit_for_year(year)
#      88 commit_hash = commit.hexsha
#      89 ck_metrics_for_single_commit(commit_hash, str(year))
# ---> 90 ru.delete_garbage("class")
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\repo_utils.py:86, in delete_garbage(keep, output)
#      84 for filename in os.listdir(output):
#      85     if not keep in filename:
# ---> 86         os.remove("output\\"+output+"\\"+filename)
#
# FileNotFoundError: [WinError 3] Impossibile trovare il percorso specificato: 'output\\output\\2017'

# %%
git_ck.commit_for_IntYear(2014,2020)

# %%
ff = git_ck.commit_measure_year(2014, "wmc")

# %%
ff
# Out:
#                                                  name        avg
# 0   0a9a05da8cef5e24dad5c188545c52e71cd375c0class.csv  45.600000
# 1   0a9a05da8cef5e24dad5c188545c52e71cd375c0method...   2.150943
# 2   0f14709f5a8af16a20e00c8d0aed0a1f6c1570ccclass.csv  45.600000
# 3   0f14709f5a8af16a20e00c8d0aed0a1f6c1570ccmethod...   2.150943
# 4   304a4935013aecdd8b854682698404c39ef3a899class.csv  45.600000
# 5   304a4935013aecdd8b854682698404c39ef3a899method...   2.150943
# 6   3baf3aa00008701df7fb8b8440a910fdb654a304class.csv  45.600000
# 7   3baf3aa00008701df7fb8b8440a910fdb654a304method...   2.150943
# 8   5c891585d2eb8ac91cf885032f95c51f6b2a734aclass.csv  45.600000
# 9   5c891585d2eb8ac91cf885032f95c51f6b2a734amethod...   2.150943
# 10  7003865c1981040e3c2f8680af71e4765329671fclass.csv  45.600000
# 11  7003865c1981040e3c2f8680af71e4765329671fmethod...   2.150943
# 12  82655a9731d2dcfe0c9aaca41591864562367b4aclass.csv  45.600000
# 13  82655a9731d2dcfe0c9aaca41591864562367b4amethod...   2.150943
# 14  831ec7707a2b28a7265c1329178d7a75d654a3f4class.csv  40.000000
# 15  831ec7707a2b28a7265c1329178d7a75d654a3f4method...   2.142857
# 16  a1962b65e4f4d45250d323cafe98a9e9d7b23578class.csv  40.000000
# 17  a1962b65e4f4d45250d323cafe98a9e9d7b23578method...   2.142857
# 18  a50306cd1f6a52d4fc5302d5ff05ddb65a0576e1class.csv  45.600000
# 19  a50306cd1f6a52d4fc5302d5ff05ddb65a0576e1method...   2.150943
# 20  ac98a65ff32e7ba45ff840c8232d338a51134330class.csv  45.600000
# 21  ac98a65ff32e7ba45ff840c8232d338a51134330method...   2.150943
# 22  c26132a05537415af71d6453575b8e3dd7c60295class.csv   7.725490
# 23  c26132a05537415af71d6453575b8e3dd7c60295method...   1.621399
# 24  d071560bb7d600aee86db9b73bd742ae4802fcb2class.csv  40.000000
# 25  d071560bb7d600aee86db9b73bd742ae4802fcb2method...   2.142857
# 26  e04ab4b0ef0dad047c58023b6b9815ce5eca1ec3class.csv  40.000000
# 27  e04ab4b0ef0dad047c58023b6b9815ce5eca1ec3method...   2.142857
# 28  e0f4aeef679074877d660d9be0f6bd2c9a36f1c6class.csv  40.000000
# 29  e0f4aeef679074877d660d9be0f6bd2c9a36f1c6method...   2.142857
# 30  e15fde71d10ac8c53f5d40458027ee1ca157fc62class.csv  45.600000
# 31  e15fde71d10ac8c53f5d40458027ee1ca157fc62method...   2.150943
# 32  f188f4660b2fda2a7e877696cf52ba53773bb1d2class.csv  45.600000
# 33  f188f4660b2fda2a7e877696cf52ba53773bb1d2method...   2.150943
# 34  f5973818fa8b48a1fbf37c2419e07f286219b3b9class.csv  45.600000
# 35  f5973818fa8b48a1fbf37c2419e07f286219b3b9method...   2.150943

# %%
git_ck.commit_measure("wmc")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> git_ck.commit_measure("wmc")
#
# TypeError: commit_measure() missing 1 required positional argument: 'commit_hash'

# %%
ru.refresh()

# %%
fc = git_ck.commit_measure_year(2017, "wmc")
# Out:
# Sto facendo cose
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> fc = git_ck.commit_measure_year(2017, "wmc")
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\git_ck.py:96, in commit_measure_year(year, measure)
#      95 def commit_measure_year(year, measure):
# ---> 96     commit_for_year(year)
#      97     result_data = []
#      98     path = os.path.abspath(year)
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\git_ck.py:90, in commit_for_year(year)
#      88 commit_hash = commit.hexsha
#      89 ck_metrics_for_single_commit(commit_hash, str(year))
# ---> 90 ru.delete_garbage("class")
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\repo_utils.py:86, in delete_garbage(keep, output)
#      84 for filename in os.listdir(output):
#      85     if not keep in filename:
# ---> 86         os.remove(output+"\\"+filename)
#      88 for filename in os.listdir(output):
#      89     df = pd.read_csv(output+"\\"+filename, sep=",")
#
# PermissionError: [WinError 5] Accesso negato: 'output\\2017'

# %%
fc
# Out:
#                                                  name       avg
# 0   0a9a05da8cef5e24dad5c188545c52e71cd375c0class.csv  45.60000
# 1   0f14709f5a8af16a20e00c8d0aed0a1f6c1570ccclass.csv  45.60000
# 2   304a4935013aecdd8b854682698404c39ef3a899class.csv   7.72549
# 3   3baf3aa00008701df7fb8b8440a910fdb654a304class.csv   7.72549
# 4   5c891585d2eb8ac91cf885032f95c51f6b2a734aclass.csv  45.60000
# 5   831ec7707a2b28a7265c1329178d7a75d654a3f4class.csv  45.60000
# 6   a1962b65e4f4d45250d323cafe98a9e9d7b23578class.csv  46.20000
# 7   c26132a05537415af71d6453575b8e3dd7c60295class.csv   7.72549
# 8   d071560bb7d600aee86db9b73bd742ae4802fcb2class.csv  45.60000
# 9   e04ab4b0ef0dad047c58023b6b9815ce5eca1ec3class.csv  45.60000
# 10  e0f4aeef679074877d660d9be0f6bd2c9a36f1c6class.csv  45.60000
# 11  f5973818fa8b48a1fbf37c2419e07f286219b3b9class.csv   7.72549
