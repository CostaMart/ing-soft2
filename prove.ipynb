# %%
import os
import model.git_ck as git_ck
import model.repo_utils as ru
import pandas as pd 
import model.process_metrics as pm
import model.spMetrics as sp
import model.chartOrganizer as co

# %%
json_list = [
    {"Commit_Hash": "5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37", "Data_del_Commit": "2014-07-19 21:56:28+02:00"},
    {"Commit_Hash": "c705eae618faa0a1ef9690a258591e6017bd9cce", "Data_del_Commit": "2014-07-19 22:16:26+02:00"},
    {"Commit_Hash": "543fee39bfbc24d5714a2a29c673efa8b5feecba", "Data_del_Commit": "2014-07-22 11:32:47+02:00"},
]

# %%
ru.repo_to_use()

# %%
lista = ru.dataCommitLink(ru.repo_to_use())

# %%
lista.head(10)
lista.head(20)
# Out:
#                                  Commit Hash            Data del Commit
# 0   117c84823b376902cf208c2babf1dc7f4142c912  2014-05-06 07:06:34-07:00
# 1   3f5e8ec805934ca9b0db905d093ef9949bbaf3fb  2014-05-19 08:02:02+02:00
# 2   7262545c53e58195fb58696d0e8cc5835517f527  2014-05-19 08:06:24+02:00
# 3   43f7cfecbd273c5cac4a7c3083db5b31cb67921e  2014-07-04 09:20:53+02:00
# 4   618d7f4ddf0f8e3dec259cc0d0ee2e588bf4ab65  2014-07-04 09:22:30+02:00
# 5   3e3d55f9fffb4c22c64a1e93c7e334fb9e2b1d9d  2014-07-19 20:21:13+02:00
# 6   c9dd0667e398d77652ffaf3ff03f46ada4019fc0  2014-07-19 21:53:27+02:00
# 7   5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37  2014-07-19 21:56:28+02:00
# 8   c705eae618faa0a1ef9690a258591e6017bd9cce  2014-07-19 22:16:26+02:00
# 9   543fee39bfbc24d5714a2a29c673efa8b5feecba  2014-07-22 11:32:47+02:00
# 10  65714a05c0b77db4d43fe2f290a1c46a2f3cee75  2014-07-22 11:57:57+02:00
# 11  724e2d9c82fc25ed2491b4734b90f9d557ca3dbe  2014-07-22 14:43:12+02:00
# ...

# %%
df = sp.generate_metrics_ck("5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37","73fdb5c54e15ecc95e1cb18a43a262db3579b5d3")

# %%
df
# Out:
#                                          Commit Hash  \
# 0  5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37class.csv
# 1  c705eae618faa0a1ef9690a258591e6017bd9cceclass.csv
# 2  543fee39bfbc24d5714a2a29c673efa8b5feecbaclass.csv
# 3  65714a05c0b77db4d43fe2f290a1c46a2f3cee75class.csv
# 4  724e2d9c82fc25ed2491b4734b90f9d557ca3dbeclass.csv
# 5  aedb14e73f1ff786f3a05b7f99c37b53cd5d882fclass.csv
# 6  52667655b4b55a632d52830af9250e2d3e734f6dclass.csv
# 7  8aa78ef6b718ed157c0557bdb238338a47305da7class.csv
# 8  73fdb5c54e15ecc95e1cb18a43a262db3579b5d3class.csv
#
#              Data del Commit        cbo       wmc       dit  noc        rfc  \
# 0  2014-07-19 21:56:28+02:00  10.130435  7.130435  1.565217  0.0  16.217391
# 1  2014-07-19 22:16:26+02:00  10.130435  7.130435  1.565217  0.0  16.217391
# 2  2014-07-22 11:32:47+02:00  10.130435  7.152174  1.565217  0.0  16.260870
# 3  2014-07-22 11:57:57+02:00  10.130435  7.173913  1.565217  0.0  16.260870
# ...

# %%
noc = co.noc(df)

# %%
noc
# Out:
#              Data del Commit  noc
# 0  2014-07-19 21:56:28+02:00  0.0
# 1  2014-07-19 22:16:26+02:00  0.0
# 2  2014-07-22 11:32:47+02:00  0.0
# 3  2014-07-22 11:57:57+02:00  0.0
# 4  2014-07-22 14:43:12+02:00  0.0
# 5  2014-07-25 12:31:50+02:00  0.0
# 6  2014-07-25 14:08:22+02:00  0.0
# 7  2014-07-25 14:11:34+02:00  0.0
# 8  2014-07-30 17:31:45+02:00  0.0

# %%
ru.checkout_commit("5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37")

# %%
df2 = sp.generate_metrics_ck(json_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df2 = sp.generate_metrics_ck(json_list)
#
# NameError: name 'sp' is not defined

# %%
df2
# Out:
#                                          Commit Hash  \
# 0  5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37class.csv
# 1  c705eae618faa0a1ef9690a258591e6017bd9cceclass.csv
# 2  543fee39bfbc24d5714a2a29c673efa8b5feecbaclass.csv
#
#              Data del Commit        cbo       wmc       dit  noc        rfc  \
# 0  2014-07-19 21:56:28+02:00  10.130435  7.130435  1.565217  0.0  16.217391
# 1  2014-07-19 22:16:26+02:00  10.130435  7.130435  1.565217  0.0  16.217391
# 2  2014-07-22 11:32:47+02:00  10.130435  7.152174  1.565217  0.0  16.260870
#
#         lcom
# 0  74.521739
# 1  74.521739
# 2  74.521739

# %%
plot = co.dit(df2)
plot.show()

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df2
#
# NameError: name 'df2' is not defined

# %%
anni = ru.extract_years_from_commits()

# %%
for element in anni:
    print(element)
# Out:
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2014
# 2015

# %%
   
try:
    ru.check_repo()
    ru.check_folder()
except:
    print("Warning")

# %%
ru.checkout_commit("da34c0fa2e034aef9dc789bdfc9dab55dc4dfbdf")
# Out:
# Checkout effettuato con successo al commit da34c0fa2e034aef9dc789bdfc9dab55dc4dfbdf.

# %%
measures = ["cbo", "wmc", "dit", "noc"]

# %%
cmr = git_ck.commit_measure_release(measures)
# Out:
# Errore nell'esecuzione del comando 'git tag': fatal: not a git repository: 'c:\Users\simon\Documents\GitHub\ing-soft2\repository\.git'
#
# Nessun commit disponibile per il tag di rilascio specificato.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> cmr = git_ck.commit_measure_release(measures)
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\model\git_ck.py:131, in commit_measure_release(measures, folder)
#     129     result_data.append({"Commit Hash": name, **metric_averages})
#     130 result_df = pd.DataFrame(result_data)
# --> 131 rel['Commit Hash'] = rel['Commit Hash']+'class.csv'
#     132 result = rel.merge(result_df, on ="Commit Hash")
#     133 return result
#
# ...

# %%
cmr
# Out:
#        Tag                                        Commit Hash  \
# 0     v1.0  7262545c53e58195fb58696d0e8cc5835517f527class.csv
# 1     v1.1  46e7bd4a544c66aa8a2d2a85719f38920123b3d5class.csv
# 2   v1.2.1  a0291e2fbec8b89f35bd61c1e4c68fe85e527f93class.csv
# 3     v1.3  c7f9084a61264f463b67f2f920a90ddb324c04f2class.csv
# 4     v1.4  2625673fe6bdcdfdbec951af8f20809eec49f092class.csv
# 5     v1.5  6c7748eebd5fba4bdc83a4497b546aacfe20e45eclass.csv
# 6     v1.6  5c891585d2eb8ac91cf885032f95c51f6b2a734aclass.csv
# 7     v1.7  7c665511b37897961a2e693ba80a2a9ebf1b6ee8class.csv
# 8     v1.8  4bddc1e203e3785f4a6046625abe355a8676da9bclass.csv
# 9     v2.0  7ddfddacc817f3d0cf813f4e39e4397a2896cc72class.csv
# 10    v2.1  677aa5b5dbc9f2f0cd89518ba8d16725dd7703a0class.csv
# 11  v2.1.1  d56bb32f4ad833cda0acc2c63cb72ea151257d24class.csv
# 12  v2.1.2  ba8e26ece080b799e5a6ec66a9ae88216eae90acclass.csv
# 13  v2.1.3  e6eca6ea36a8e008f12b480413eb1311733fca56class.csv
# ...

# %%
lista, folder= ru.inizia_analisi(tag= "v2.1.2", folder="repository\\fxgraphics2d")
# Out:
# Checkout effettuato con successo al commit ba8e26ece080b799e5a6ec66a9ae88216eae90ac.

# %%
lista, folder
# Out:
# ('Commit Hash', 'Data del Commit')

# %%
lf = git_ck.commit_measure_interval(measures, lista, index=10, folder=folder )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\simon\Documents\GitHub\ing-soft2\prove.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simon/Documents/GitHub/ing-soft2/prove.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> lf = git_ck.commit_measure_interval(measures, lista, index=10, folder=folder )
#
# File c:\Users\simon\Documents\GitHub\ing-soft2\model\git_ck.py:153, in commit_measure_interval(measures, df, index, folder)
#     151 def commit_measure_interval(measures, df, index, folder = "repository"):
#     152     """ Questo metodo calcola le metriche per l'intervallo e fa la media delle metriche richieste per ogni commit"""
# --> 153     commit = analyze_commits_for_interval(df, index, folder)
#     154     commit['Commit Hash'] = commit['Commit Hash'] + 'class.csv'
#     155     result_data = []
#
# ...

# %%
lf
# Out:
#                                          Commit Hash  \
# 0  5cc308294cf689517d27476eacd87d2e81952fe5class.csv
# 1  05ff4aee36281775922cd0594f7505a49fa165c9class.csv
# 2  1a2ec11e85b2a93b82857f932105100b720146aaclass.csv
# 3  9905d471eb8d5ca2da3d886170ec207f298bdd3bclass.csv
# 4  1ec83be725aa92b9a41c959cdc9251c4ba90bc97class.csv
#
#              Data del Commit  cbo  wmc  dit  noc
# 0  2023-10-25 18:03:05+02:00  NaN  NaN  NaN  NaN
# 1  2023-10-25 18:32:08+02:00  NaN  NaN  NaN  NaN
# 2  2023-10-25 19:25:20+02:00  NaN  NaN  NaN  NaN
# 3  2023-10-26 10:29:51+02:00  NaN  NaN  NaN  NaN
# 4  2023-10-26 14:59:03+02:00  NaN  NaN  NaN  NaN

# %%
listamezza = ru.sfoglia_commit(lista, 150)
listamezza
# Out:
#                             Titolo del Commit            Data del Commit
# 150  cf00649b16baf32fa4fa4bf872ec02def219f83e  2018-07-05 05:59:16+02:00
# 151  4cd172f2b7fd9d74f2bebd7802d65c9d7e5fc224  2018-07-05 06:00:24+02:00
# 152  7c665511b37897961a2e693ba80a2a9ebf1b6ee8  2018-07-05 06:01:29+02:00
# 153  0f4077a6c4503e71c44557c6c10e920b2bb7b1cd  2018-07-05 06:36:43+02:00
# 154  03c9ef2c8f0db842dce521d5a688fe12faaccbd4  2019-01-30 23:10:10+01:00
# 155  11f57d5f20fe0b6dd8a9d944c21e298d85cf8db4  2019-01-30 23:14:35+01:00
# 156  eb1f6586bb1bd2117841e3c810073fff4f6afd12  2019-01-30 23:23:24+01:00
# 157  75a73bd87c6cf5364a3067b579eae9636e40199d  2019-01-30 23:25:32+01:00
# 158  4bddc1e203e3785f4a6046625abe355a8676da9b  2019-02-07 22:19:32+01:00
# 159  be47c725f86d7a339770113c685b136b3eb892c8  2020-02-25 18:05:02+01:00

# %%
pd=ru.dataCommit()
pd.to_csv("C:\\Users\\simon\\Desktop\\dati importanti\\committo.csv")

# %%
commit_hash = '3baf3aa00008701df7fb8b8440a910fdb654a304'
git_ck.ck_metrics_for_single_commit(commit_hash)
result_df= pd.read_csv(os.path.abspath('output\\3baf3aa00008701df7fb8b8440a910fdb654a304class.csv'))

# %%
result_df
# Out:
#                                                 file  \
# 0  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 1  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 2  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 3  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
# 4  c:\Users\simon\Documents\GitHub\ing-soft2\Repo...
#
#                                   class        type  cbo  cboModified  fanin  \
# 0             org.jfree.fx.FXGraphics2D       class   17           18      1
# 1         org.jfree.fx.FXGraphicsDevice       class    1            3      2
# 2  org.jfree.fx.FXGraphicsConfiguration       class    2            4      2
# 3                  org.jfree.fx.FXHints       class    1            1      0
# 4              org.jfree.fx.FXHints$Key  innerclass    0            0      0
#
#    fanout  wmc  dit  noc  ...  assignmentsQty  mathOperationsQty  \
# 0      17  208    3    0  ...             161                 18
# ...

# %%
measures = ["cbo", "wmc", "dit", "noc"]
git_ck.commit_measure(measures ,commit_hash)
# Out:
#                                   class  cbo  wmc  dit  noc
# 0             org.jfree.fx.FXGraphics2D   17  208    3    0
# 1         org.jfree.fx.FXGraphicsDevice    1    5    2    0
# 2  org.jfree.fx.FXGraphicsConfiguration    2   10    2    0
# 3                  org.jfree.fx.FXHints    1    1    2    0
# 4              org.jfree.fx.FXHints$Key    0    4    2    0

# %%
git_ck.commit_measure_avg("wmc" ,commit_hash+"class.csv")
# Out:
# 45.6

# %%
metrics = ["wmc", "dit", "noc", "cbo"]
ff = git_ck.commit_measure_year(2014, metrics)

# %%
ff
# Out:
#                                                  name       wmc       dit  \
# 0   117c84823b376902cf208c2babf1dc7f4142c912class.csv       NaN       NaN
# 1   3e3d55f9fffb4c22c64a1e93c7e334fb9e2b1d9dclass.csv  7.130435  1.565217
# 2   3f5e8ec805934ca9b0db905d093ef9949bbaf3fbclass.csv  7.065217  1.565217
# 3   43f7cfecbd273c5cac4a7c3083db5b31cb67921eclass.csv  7.130435  1.565217
# 4   46e7bd4a544c66aa8a2d2a85719f38920123b3d5class.csv  7.217391  1.565217
# 5   52667655b4b55a632d52830af9250e2d3e734f6dclass.csv  7.217391  1.565217
# 6   5279dddcdf9ebfd5a4f4b7d5a5d595dcc86abe37class.csv  7.130435  1.565217
# 7   543fee39bfbc24d5714a2a29c673efa8b5feecbaclass.csv  7.152174  1.565217
# 8   618d7f4ddf0f8e3dec259cc0d0ee2e588bf4ab65class.csv  7.130435  1.565217
# 9   65714a05c0b77db4d43fe2f290a1c46a2f3cee75class.csv  7.173913  1.565217
# 10  724e2d9c82fc25ed2491b4734b90f9d557ca3dbeclass.csv  7.217391  1.565217
# 11  7262545c53e58195fb58696d0e8cc5835517f527class.csv  7.065217  1.565217
# ...

# %%
pm.calcola_numero_bug_fix_per_commit_specifico(commit_hash="73fdb5c54e15ecc95e1cb18a43a262db3579b5d3")
# Out:
# 1
